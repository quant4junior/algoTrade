# %%
from keras.layers import Input, Dense, Conv1D, MaxPooling1D, UpSampling1D, BatchNormalization, LSTM, RepeatVector
from keras.models import Model
from keras.models import model_from_json
from keras import regularizers
import datetime
import time
import requests as req
import json
import pandas as pd
import pickle
import os
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Using TensorFlow backend.
# Populating the interactive namespace from numpy and matplotlib

# %%
window_length = 10
encoding_dim = 3
epochs = 100
test_samples = 200

import pandas as pd
path = '../../data/ch05/s&p500.csv'
snp500_df = pd.read_csv(path,usecols=['Adj Close'])
snp500_df['pct_change'] = snp500_df['Adj Close'].pct_change()
snp500_df['log_ret'] = np.log(snp500_df['Adj Close']) - np.log(snp500_df['Adj Close'].shift(1))

def plot_examples(stock_input, stock_decoded):
    n = 10  
    plt.figure(figsize=(20, 4))
    for i, idx in enumerate(list(np.arange(0, test_samples, 20))):
        # display original
        ax = plt.subplot(2, n, i + 1)
        if i == 0:
            ax.set_ylabel("Input", fontweight=600)
        else:
            ax.get_yaxis().set_visible(False)
        plt.plot(stock_input[idx])
        ax.get_xaxis().set_visible(False)
        

        # display reconstruction
        ax = plt.subplot(2, n, i + 1 + n)
        if i == 0:
            ax.set_ylabel("Output", fontweight=600)
        else:
            ax.get_yaxis().set_visible(False)
        plt.plot(stock_decoded[idx])
        ax.get_xaxis().set_visible(False)
        
        
def plot_history(history):
    plt.figure(figsize=(15, 5))
    ax = plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"])
    plt.title("Train loss")
    ax = plt.subplot(1, 2, 2)
    plt.plot(history.history["val_loss"])
    plt.title("Test loss")

# %%
# plt.figure(figsize=(20,10))
# plt.plot(np.array(data)[:,1])
# plt.plot(snp500_df)

# %%
# snp500_df['log_ret'] = np.log(snp500_df['Adj Close']) - np.log(snp500_df['Adj Close'].shift(1))
# snp500_df['log_ret'] = np.log(snp500_df['pct_change'])

# %%
# snp500_df['log_ret'].plot()

# %%
# scaler = MinMaxScaler()
# x_train_nonscaled = np.array([snp500_df['log_ret'].values[i-window_length:i].reshape(-1, 1) for i in tqdm(range(window_length+1,len(snp500_df['log_ret'])))])
# x_train = np.array([scaler.fit_transform(snp500_df['log_ret'].values[i-window_length:i].reshape(-1, 1)) for i in tqdm(range(window_length+1,len(snp500_df['log_ret'])))])

# %%
scaler = MinMaxScaler()
x_train_nonscaled = np.array([snp500_df['log_ret'].values[i-window_length:i].reshape(-1, 1) for i in range(window_length+1,len(snp500_df['log_ret']))])
x_train = np.array([scaler.fit_transform(snp500_df['log_ret'].values[i-window_length:i].reshape(-1, 1)) for i in range(window_length+1,len(snp500_df['log_ret']))])

x_test = x_train[-test_samples:]
x_train = x_train[:-test_samples]

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

print("테스트 데이터 비중: {}%".format((test_samples/len(x_train))*100))
# Out:
# 테스트 데이터 비중: 4.146796599626788%

# %% [markdown]
# ##  첫 번째 모델 : 단순 MLP 오토인코더

# %%
x_train_simple = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test_simple = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# this is our input placeholder
input_window = Input(shape=(window_length,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_window)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(window_length, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_window, decoded)

# this model maps an input to its encoded representation
encoder = Model(input_window, encoded)


autoencoder.summary()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train_simple, x_train_simple,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test_simple, x_test_simple))

decoded_stocks = autoencoder.predict(x_test_simple)
plot_history(history)
plot_examples(x_test_simple, decoded_stocks)
# Out:
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 33
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 4823 samples, validate on 200 samples
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 4823/4823 [==============================] - 1s 151us/step - loss: 0.6943 - val_loss: 0.6942
# Epoch 2/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6935 - val_loss: 0.6934
# Epoch 3/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6928 - val_loss: 0.6926
# Epoch 4/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6921 - val_loss: 0.6919
# Epoch 5/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6915 - val_loss: 0.6913
# Epoch 6/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6909 - val_loss: 0.6908
# Epoch 7/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6905 - val_loss: 0.6903
# Epoch 8/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6900 - val_loss: 0.6898
# Epoch 9/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6896 - val_loss: 0.6893
# Epoch 10/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6891 - val_loss: 0.6888
# Epoch 11/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.
100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6515 - val_loss: 0.6484
# Epoch 76/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6511 - val_loss: 0.6480
# Epoch 77/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6507 - val_loss: 0.6476
# Epoch 78/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6503 - val_loss: 0.6471
# Epoch 79/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6499 - val_loss: 0.6467
# Epoch 80/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6495 - val_loss: 0.6463
# Epoch 81/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6491 - val_loss: 0.6459
# Epoch 82/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6487 - val_loss: 0.6455
# Epoch 83/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6483 - val_loss: 0.6451
# Epoch 84/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6480 - val_loss: 0.6448
# Epoch 85/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6476 - val_loss: 0.6444
# Epoch 86/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6473 - val_loss: 0.6440
# Epoch 87/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6470 - val_loss: 0.6437
# Epoch 88/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6466 - val_loss: 0.6434
# Epoch 89/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6463 - val_loss: 0.6430
# Epoch 90/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6460 - val_loss: 0.6427
# Epoch 91/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6457 - val_loss: 0.6424
# Epoch 92/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6454 - val_loss: 0.6421
# Epoch 93/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6451 - val_loss: 0.6418
# Epoch 94/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6448 - val_loss: 0.6415
# Epoch 95/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6445 - val_loss: 0.6412
# Epoch 96/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6443 - val_loss: 0.6409
# Epoch 97/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6440 - val_loss: 0.6406
# Epoch 98/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6437 - val_loss: 0.6403
# Epoch 99/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6435 - val_loss: 0.6401
# Epoch 100/100
# 4823/4823 [==============================] - 0s 2us/step - loss: 0.6432 - val_loss: 0.6398

# %% [markdown]
# ## - 두 번째 모델 : Deep 오토인코더

# %%
x_train_deep = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test_deep = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

input_window = Input(shape=(window_length,))

x = Dense(6, activation='relu')(input_window)
x = BatchNormalization()(x)
encoded = Dense(encoding_dim, activation='relu')(x)
# "decoded" is the lossy reconstruction of the input

x = Dense(6, activation='relu')(encoded)
x = BatchNormalization()(x)
decoded = Dense(window_length, activation='sigmoid')(x)

# this model maps an input to its reconstruction
autoencoder = Model(input_window, decoded)

# this model maps an input to its encoded representation
encoder = Model(input_window, encoded)

autoencoder.summary()

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train_deep, x_train_deep,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test_deep, x_test_deep))

decoded_stocks = autoencoder.predict(x_test_deep)
plot_history(history)
plot_examples(x_test_deep, decoded_stocks)
# Out:
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 66
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 6)                 24
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 21
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 24
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6)                 24
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                70
# =================================================================
# Total params: 229
# Trainable params: 205
# Non-trainable params: 24
# _________________________________________________________________
# Train on 4823 samples, validate on 200 samples
# Epoch 1/100
# 4823/4823 [==============================] - 1s 155us/step - loss: 0.7473 - val_loss: 0.7417
# Epoch 2/100
# 4823/4823 [==============================] - 0s 5us/step - loss: 0.7423 - val_loss: 0.7345
# Epoch 3/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.7380 - val_loss: 0.7282
# Epoch 4/100
# 4823/4823 [==============================] - 0s 5us/step - loss: 0.7339 - val_loss: 0.7226
# Epoch 5/100
# 4823/4823 [==============================] - 0s 5us/step - loss: 0.7299 - val_loss: 0.7176
# Epoch 6/100
# 4823/4823 [==============================] - 0s 5us/step - loss: 0.7261 - val_loss: 0.7134
# Epoch 7/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.7224 - val_loss: 0.7097
# Epoch 8/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.7189 - val_loss: 0.7066
# Epoch 9/100
# 4823/4823 [==============================] - 0s 5us/step - loss: 0.7155 - val_loss: 0.7040
# Epoch 10/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.7122 - val_loss: 0.7019
# Epoch 11/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.7086 - val_loss: 0.7000
# Epoch 12/100
# 4823/4823 [==============================] - 0s 5us/step - loss: 0.7053 - val_loss: 0.6983
# Epoch 13/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.7019 - val_loss: 0.6969
# Epoch 14/100
# 4823/4823 [==============================] - 0s 5us/step - loss: 0.6994 - val_loss: 0.6957
# Epoch 15/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6974 - val_loss: 0.6948
# Epoch 16/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6958 - val_loss: 0.6940
# Epoch 17/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6945 - val_loss: 0.6933
# Epoch 18/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6933 - val_loss: 0.6926
# Epoch 19/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6924 - val_loss: 0.6920
# Epoch 20/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.
100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6566 - val_loss: 0.6614
# Epoch 83/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6564 - val_loss: 0.6612
# Epoch 84/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6563 - val_loss: 0.6610
# Epoch 85/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6562 - val_loss: 0.6608
# Epoch 86/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6560 - val_loss: 0.6607
# Epoch 87/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6558 - val_loss: 0.6605
# Epoch 88/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6557 - val_loss: 0.6603
# Epoch 89/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6556 - val_loss: 0.6601
# Epoch 90/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6554 - val_loss: 0.6599
# Epoch 91/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6552 - val_loss: 0.6597
# Epoch 92/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6551 - val_loss: 0.6595
# Epoch 93/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6550 - val_loss: 0.6594
# Epoch 94/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6549 - val_loss: 0.6592
# Epoch 95/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6548 - val_loss: 0.6591
# Epoch 96/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6547 - val_loss: 0.6590
# Epoch 97/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6545 - val_loss: 0.6589
# Epoch 98/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6544 - val_loss: 0.6588
# Epoch 99/100
# 4823/4823 [==============================] - 0s 4us/step - loss: 0.6543 - val_loss: 0.6587
# Epoch 100/100
# 4823/4823 [==============================] - 0s 3us/step - loss: 0.6542 - val_loss: 0.6586

# %% [markdown]
# ## 1D Convolutional autoencoder

# %%
input_window = Input(shape=(window_length,1))
x = Conv1D(16, 3, activation="relu", padding="same")(input_window) # 10 dims
#x = BatchNormalization()(x)
x = MaxPooling1D(2, padding="same")(x) # 5 dims
x = Conv1D(1, 3, activation="relu", padding="same")(x) # 5 dims
#x = BatchNormalization()(x)
encoded = MaxPooling1D(2, padding="same")(x) # 3 dims

encoder = Model(input_window, encoded)

# 3 dimensions in the encoded layer

x = Conv1D(1, 3, activation="relu", padding="same")(encoded) # 3 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 6 dims
x = Conv1D(16, 2, activation='relu')(x) # 5 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 10 dims
decoded = Conv1D(1, 3, activation='sigmoid', padding='same')(x) # 10 dims
autoencoder = Model(input_window, decoded)
autoencoder.summary()

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train, x_train,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test))

decoded_stocks = autoencoder.predict(x_test)
plot_history(history)
plot_examples(x_test, decoded_stocks)
# Out:
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 10, 1)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 10, 16)            64
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 5, 16)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 5, 1)              49
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 3, 1)              0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 3, 1)              4
# _________________________________________________________________
# up_sampling1d_1 (UpSampling1 (None, 6, 1)              0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 5, 16)             48
# _________________________________________________________________
# up_sampling1d_2 (UpSampling1 (None, 10, 16)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 1)             49
# =================================================================
# Total params: 214
# Trainable params: 214
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4823 samples, validate on 200 samples
# Epoch 1/100
# 4823/4823 [==============================] - 1s 169us/step - loss: 0.6932 - val_loss: 0.6932
# Epoch 2/100
# 4823/4823 [==============================] - 0s 18us/step - loss: 0.6931 - val_loss: 0.6932
# Epoch 3/100
# 4823/4823 [==============================] - 0s 17us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 4/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 5/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 6/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 7/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 8/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 9/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 10/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 0.6931 - val_loss: 0.6932
# Epoch 11/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6931 - val_loss: 0.6932
# Epoch 12/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 13/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 14/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 15/100
# 4823/4823 [==============================] - 0s 16us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 16/100
# 4823/4823 [==============================] - 0s 17us/step - loss: 0.6931 - val_loss: 0.6933
# Epoch 17/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 0.6931 - val_loss: 0.6932
# Epoch 18/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6930 - val_loss: 0.6933
# Epoch 19/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6928 - val_loss: 0.6931
# Epoch 20/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6926 - val_loss: 0.6928
# Epoch 21/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6922 - val_loss: 0.6926
# Epoch 22/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6918 - val_loss: 0.6922
# Epoch 23/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6913 - val_loss: 0.6917
# Epoch 24/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6908 - val_loss: 0.6911
# Epoch 25/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6901 - val_loss: 0.6904
# Epoch 26/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6895 - val_loss: 0.6895
# Epoch 27/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6888 - val_loss: 0.6888
# Epoch 28/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6880 - val_loss: 0.6878
# Epoch 29/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6872 - val_loss: 0.6869
# Epoch 30/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6864 - val_loss: 0.6860
# Epoch 31/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6856 - val_loss: 0.6848
# Epoch 32/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 0.6847 - val_loss: 0.6837
# Epoch 33/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 0.6838 - val_loss: 0.6825
# Epoch 34/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6828 - val_loss: 0.6813
# Epoch 35/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.
100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6615 - val_loss: 0.6588
# Epoch 89/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6614 - val_loss: 0.6588
# Epoch 90/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6613 - val_loss: 0.6585
# Epoch 91/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6612 - val_loss: 0.6583
# Epoch 92/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6610 - val_loss: 0.6587
# Epoch 93/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6609 - val_loss: 0.6581
# Epoch 94/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6608 - val_loss: 0.6582
# Epoch 95/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 0.6607 - val_loss: 0.6581
# Epoch 96/100
# 4823/4823 [==============================] - 0s 23us/step - loss: 0.6606 - val_loss: 0.6580
# Epoch 97/100
# 4823/4823 [==============================] - 0s 16us/step - loss: 0.6605 - val_loss: 0.6579
# Epoch 98/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 0.6604 - val_loss: 0.6578
# Epoch 99/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6603 - val_loss: 0.6576
# Epoch 100/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 0.6602 - val_loss: 0.6576

# %% [markdown]
# ## LSTM (recurrent neural networks) autoencoder

# %%
inputs = Input(shape=(window_length, 1))
encoded = LSTM(encoding_dim)(inputs)

decoded = RepeatVector(window_length)(encoded)
decoded = LSTM(1, return_sequences=True)(decoded)

sequence_autoencoder = Model(inputs, decoded)
encoder = Model(inputs, encoded)
sequence_autoencoder.summary()

sequence_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = sequence_autoencoder.fit(x_train, x_train,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test))

decoded_stocks = sequence_autoencoder.predict(x_test)
plot_history(history)
plot_examples(x_test, decoded_stocks)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 10, 1)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 3)                 60
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 10, 3)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 1)             20
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4823 samples, validate on 200 samples
# Epoch 1/100
# 4823/4823 [==============================] - 1s 295us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 2/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 3/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 4/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 5/100
# 4823/4823 [==============================] - 0s 12us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 6/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 7/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 8/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 9/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 10/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 11/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 12/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 13/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 14/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 15/100
# 4823/4823 [==============================] - 0s 19us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 16/100
# 4823/4823 [==============================] - 0s 16us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 17/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 18/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 19/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 20/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 21/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 22/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 23/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 24/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 25/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 26/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 27/100
# 4823/4823 [==============================] - 0s 16us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 28/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 29/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 30/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 31/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 32/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 33/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 34/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 35/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 36/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 37/100
# 4823/4823 [==============================] - 0s 17us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 38/100
# 4823/4823 [==============================] - 0s 16us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 39/100
# 4823/4823 [==============================] - 0s 17us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 40/100
# 4823/4823 [==============================] - 0s 16us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 41/100
# 4823/4823 [==============================] - 0s 16us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 42/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 43/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 44/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 45/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 46/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 47/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 48/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 49/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 50/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 51/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 52/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 53/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 54/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 55/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 56/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 57/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 58/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 59/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 60/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 61/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 62/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 63/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 64/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 65/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 66/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 67/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 68/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 69/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 70/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 71/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 72/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 73/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 74/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 75/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 76/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 77/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 78/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 79/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 80/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 81/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 82/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 83/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 84/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 85/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 86/100
# 4823/4823 [==============================] - 0s 15us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 87/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 88/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 89/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 90/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 91/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 92/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 93/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 94/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 95/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 96/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 97/100
# 4823/4823 [==============================] - 0s 14us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 98/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 99/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619
# Epoch 100/100
# 4823/4823 [==============================] - 0s 13us/step - loss: 8.0390 - val_loss: 8.4619

# %% [markdown]
# ### Encoder를 Feature로 활용하기.

# %%
x_train_simple = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test_simple = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

input_window = Input(shape=(window_length,))
encoded = Dense(encoding_dim, activation='relu')(input_window)
decoded = Dense(window_length, activation='sigmoid')(encoded)

autoencoder = Model(input_window, decoded)

encoder = Model(input_window, encoded)


autoencoder.summary()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train_simple, x_train_simple,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test_simple, x_test_simple))

decoded_stocks = autoencoder.predict(x_test_simple)
#############
compress_x_train = encoder.predict(x_train_simple)
compress_x_test = encoder.predict(x_test_simple)

# %%
x_train_simple.shape
# Out:
# (4823, 10)

# %%
compress_x_train.shape
# Out:
# (4823, 3)

# %%
compress_x_test.shape
# Out:
# (200, 3)

# %% [markdown]
# #### 압축된 Feature 데이터를 입력값으로 전달한다.

# %%
new_feature = np.concatenate([compress_x_train,compress_x_test])
tmp_df = pd.DataFrame(new_feature,columns=['comp_fe1','comp_fe2','comp_fe3'])

# %%
tmp_df
# Out:
#       comp_fe1  comp_fe2  comp_fe3
# 0     0.972157      -0.0  0.413707
# 1     0.937324      -0.0  0.846234
# 2    -0.000000      -0.0  0.899268
# 3     0.001353      -0.0  0.367686
# 4     1.067106      -0.0 -0.000000
# ...        ...       ...       ...
# 5018 -0.000000      -0.0  0.279579
# 5019  0.859803      -0.0  0.214271
# 5020  1.798313      -0.0  0.719596
# 5021 -0.000000      -0.0  0.323553
# 5022 -0.000000      -0.0  0.279313
#
# [5023 rows x 3 columns]

# %%
import pandas as pd
path = '../data/ch05/s&p500.csv'
snp500_df = pd.read_csv(path,usecols=['Adj Close'])
snp500_df['pct_change'] = snp500_df['Adj Close'].pct_change()
snp500_df['log_ret'] = np.log(snp500_df['Adj Close']) - np.log(snp500_df['Adj Close'].shift(1))

# %%
snp500_df.loc[11:].reset_index(drop=True).join(tmp_df,how='left')
# Out:
#         Adj Close  pct_change   log_ret  comp_fe1  comp_fe2  comp_fe3
# 0     1455.140015   -0.006832 -0.006856  0.972157      -0.0  0.413707
# 1     1455.900024    0.000522  0.000522  0.937324      -0.0  0.846234
# 2     1445.569946   -0.007095 -0.007121 -0.000000      -0.0  0.899268
# 3     1441.359985   -0.002912 -0.002917  0.001353      -0.0  0.367686
# 4     1401.530029   -0.027634 -0.028023  1.067106      -0.0 -0.000000
# ...           ...         ...       ...       ...       ...       ...
# 5018  3240.020020    0.000034  0.000034 -0.000000      -0.0  0.279579
# 5019  3221.290039   -0.005781 -0.005798  0.859803      -0.0  0.214271
# 5020  3230.780029    0.002946  0.002942  1.798313      -0.0  0.719596
# 5021  3257.850098    0.008379  0.008344 -0.000000      -0.0  0.323553
# 5022  3234.850098   -0.007060 -0.007085 -0.000000      -0.0  0.279313
#
# [5023 rows x 6 columns]

# %%
snp500_df.shape
# Out:
# (5034, 3)

# %%
sample_df[new_feature] = normalized

df['next_rtn'] = df['Close'] / df['Open'] -1

# %%
# encoding result
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# classification train data
reducted_x_train = encoder.predict(x_train)
reducted_x_test = encoder.predict(x_test)

# train classifier
model=Sequential()
model.add(Dense(64, activation='relu', input_dim=encoding_dim))
model.add(layers.Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# final result
history = model.fit(reducted_x_train, y_train, epochs=10, batch_size=100, validation_split=0.2)
performance_test = model.evaluate(reducted_x_test, y_test, batch_size=100)
print('Test Loss and Accuracy ->', performance_test)

# %%
df = pd.DataFrame(np.array(data)[:,1], columns=['price'])
df['pct_change'] = df.price.pct_change()
df['log_ret'] = np.log(df.price) - np.log(df.price.shift(1))

# %%
df.head()
# Out:
#     price  pct_change   log_ret
# 0  318.19         NaN       NaN
# 1  316.90   -0.004054 -0.004062
# 2  316.91    0.000032  0.000032
# 3  317.27    0.001136  0.001135
# 4  314.05   -0.010149 -0.010201

# %%
scaler = MinMaxScaler()
x_train_nonscaled = np.array([df['log_ret'].values[i-window_length:i].reshape(-1, 1) for i in tqdm(range(window_length+1,len(df['log_ret'])))])
x_train = np.array([scaler.fit_transform(df['log_ret'].values[i-window_length:i].reshape(-1, 1)) for i in tqdm(range(window_length+1,len(df['log_ret'])))])

x_test = x_train[-test_samples:]
x_train = x_train[:-test_samples]

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 36153/36153 [00:00<00:00, 222255.45it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 36153/36153 [00:05<00:00, 7062.04it/s]

# %%
plt.figure(figsize=(20,10))
plt.plot(np.array(data)[:,1])

# %%
print("Percentage of test data: {}%".format((test_samples/len(x_train))*100))
# Out:
# Percentage of test data: 5.85600093696015%

# %% [markdown]
# # Simple feed-forward autoencoder

# %%
x_train_simple = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test_simple = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# this is our input placeholder
input_window = Input(shape=(window_length,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_window)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(window_length, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_window, decoded)

# this model maps an input to its encoded representation
encoder = Model(input_window, encoded)


autoencoder.summary()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train_simple, x_train_simple,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test_simple, x_test_simple))

decoded_stocks = autoencoder.predict(x_test_simple)
# Out:
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 33
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 34153 samples, validate on 2000 samples
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 34153/34153 [==============================] - 1s 27us/step - loss: 0.6957 - val_loss: 0.6916
# Epoch 2/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6893 - val_loss: 0.6867
# Epoch 3/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6849 - val_loss: 0.6826
# Epoch 4/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6809 - val_loss: 0.6787
# Epoch 5/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6770 - val_loss: 0.6748
# Epoch 6/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6733 - val_loss: 0.6711
# Epoch 7/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6696 - val_loss: 0.6675
# Epoch 8/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6661 - val_loss: 0.6641
# Epoch 9/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6628 - val_loss: 0.6608
# Epoch 10/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6597 - val_loss: 0.6577
# Epoch 11/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6566 - val_loss: 0.6547
# Epoch 12/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6536 - val_loss: 0.6517
# Epoch 13/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6508 - val_loss: 0.6490
# Epoch 14/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6481 - val_loss: 0.6463
# Epoch 15/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6456 - val_loss: 0.6439
# Epoch 16/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6432 - val_loss: 0.6418
# Epoch 17/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6411 - val_loss: 0.6398
# Epoch 18/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6392 - val_loss: 0.6380
# Epoch 19/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6376 - val_loss: 0.6365
# Epoch 20/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6360 - val_loss: 0.6351
# Epoch 21/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6347 - val_loss: 0.6338
# Epoch 22/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6334 - val_loss: 0.6327
# Epoch 23/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6323 - val_loss: 0.6316
# Epoch 24/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6312 - val_loss: 0.6307
# Epoch 25/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6302 - val_loss: 0.6297
# Epoch 26/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6293 - val_loss: 0.6289
# Epoch 27/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6284 - val_loss: 0.6281
# Epoch 28/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6276 - val_loss: 0.6273
# Epoch 29/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6268 - val_loss: 0.6266
# Epoch 30/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6260 - val_loss: 0.6259
# Epoch 31/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6253 - val_loss: 0.6252
# Epoch 32/100
# 34153/34153 [==============================] - 0s 4us/step - loss: 0.6246 - val_loss: 0.6246
# Epoch 33/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6239 - val_loss: 0.6240
# Epoch 34/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6233 - val_loss: 0.6234
# Epoch 35/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6227 - val_loss: 0.6229
# Epoch 36/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6221 - val_loss: 0.6224
# Epoch 37/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6216 - val_loss: 0.6219
# Epoch 38/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6211 - val_loss: 0.6214
# Epoch 39/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6206 - val_loss: 0.6210
# Epoch 40/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6201 - val_loss: 0.6206
# Epoch 41/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6197 - val_loss: 0.6202
# Epoch 42/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6192 - val_loss: 0.6198
# Epoch 43/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6188 - val_loss: 0.6194
# Epoch 44/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6184 - val_loss: 0.6191
# Epoch 45/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6180 - val_loss: 0.6188
# Epoch 46/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6177 - val_loss: 0.6185
# Epoch 47/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6173 - val_loss: 0.6182
# Epoch 48/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6170 - val_loss: 0.6179
# Epoch 49/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6167 - val_loss: 0.6177
# Epoch 50/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6164 - val_loss: 0.6174
# Epoch 51/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6161 - val_loss: 0.6172
# Epoch 52/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6159 - val_loss: 0.6170
# Epoch 53/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6156 - val_loss: 0.6168
# Epoch 54/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6154 - val_loss: 0.6166
# Epoch 55/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6152 - val_loss: 0.6164
# Epoch 56/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6149 - val_loss: 0.6163
# Epoch 57/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6147 - val_loss: 0.6161
# Epoch 58/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6145 - val_loss: 0.6160
# Epoch 59/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6144 - val_loss: 0.6158
# Epoch 60/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6142 - val_loss: 0.6157
# Epoch 61/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6140 - val_loss: 0.6156
# Epoch 62/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6139 - val_loss: 0.6154
# Epoch 63/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6137 - val_loss: 0.6153
# Epoch 64/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6136 - val_loss: 0.6152
# Epoch 65/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6134 - val_loss: 0.6151
# Epoch 66/100
# 34153/34153 [==============================] - 0s 4us/step - loss: 0.6133 - val_loss: 0.6150
# Epoch 67/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6132 - val_loss: 0.6149
# Epoch 68/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6130 - val_loss: 0.6149
# Epoch 69/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6129 - val_loss: 0.6148
# Epoch 70/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6128 - val_loss: 0.6147
# Epoch 71/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6127 - val_loss: 0.6146
# Epoch 72/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6126 - val_loss: 0.6146
# Epoch 73/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6125 - val_loss: 0.6145
# Epoch 74/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6124 - val_loss: 0.6144
# Epoch 75/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6124 - val_loss: 0.6144
# Epoch 76/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6123 - val_loss: 0.6143
# Epoch 77/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6122 - val_loss: 0.6143
# Epoch 78/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6121 - val_loss: 0.6142
# Epoch 79/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6121 - val_loss: 0.6141
# Epoch 80/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6120 - val_loss: 0.6141
# Epoch 81/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6119 - val_loss: 0.6140
# Epoch 82/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6119 - val_loss: 0.6140
# Epoch 83/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6118 - val_loss: 0.6139
# Epoch 84/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6117 - val_loss: 0.6139
# Epoch 85/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6117 - val_loss: 0.6139
# Epoch 86/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6116 - val_loss: 0.6138
# Epoch 87/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6116 - val_loss: 0.6138
# Epoch 88/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6115 - val_loss: 0.6138
# Epoch 89/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6115 - val_loss: 0.6137
# Epoch 90/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6114 - val_loss: 0.6137
# Epoch 91/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6114 - val_loss: 0.6137
# Epoch 92/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6113 - val_loss: 0.6136
# Epoch 93/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6113 - val_loss: 0.6136
# Epoch 94/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6113 - val_loss: 0.6135
# Epoch 95/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6112 - val_loss: 0.6135
# Epoch 96/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6112 - val_loss: 0.6135
# Epoch 97/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6112 - val_loss: 0.6134
# Epoch 98/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6111 - val_loss: 0.6134
# Epoch 99/100
# 34153/34153 [==============================] - 0s 2us/step - loss: 0.6111 - val_loss: 0.6134
# Epoch 100/100
# 34153/34153 [==============================] - 0s 3us/step - loss: 0.6111 - val_loss: 0.6134

# %%
plot_history(history)
plot_examples(x_test_simple, decoded_stocks)

# %% [markdown]
# # 1D Convolutional autoencoder

# %%
input_window = Input(shape=(window_length,1))
x = Conv1D(16, 3, activation="relu", padding="same")(input_window) # 10 dims
#x = BatchNormalization()(x)
x = MaxPooling1D(2, padding="same")(x) # 5 dims
x = Conv1D(1, 3, activation="relu", padding="same")(x) # 5 dims
#x = BatchNormalization()(x)
encoded = MaxPooling1D(2, padding="same")(x) # 3 dims

encoder = Model(input_window, encoded)

# 3 dimensions in the encoded layer

x = Conv1D(1, 3, activation="relu", padding="same")(encoded) # 3 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 6 dims
x = Conv1D(16, 2, activation='relu')(x) # 5 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 10 dims
decoded = Conv1D(1, 3, activation='sigmoid', padding='same')(x) # 10 dims
autoencoder = Model(input_window, decoded)
autoencoder.summary()

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(x_train, x_train,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test))

decoded_stocks = autoencoder.predict(x_test)
# Out:
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 10, 1)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 10, 16)            64
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 5, 16)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 5, 1)              49
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 3, 1)              0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 3, 1)              4
# _________________________________________________________________
# up_sampling1d_1 (UpSampling1 (None, 6, 1)              0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 5, 16)             48
# _________________________________________________________________
# up_sampling1d_2 (UpSampling1 (None, 10, 16)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 10, 1)             49
# =================================================================
# Total params: 214
# Trainable params: 214
# Non-trainable params: 0
# _________________________________________________________________
# Train on 34153 samples, validate on 2000 samples
# Epoch 1/100
# 34153/34153 [==============================] - 2s 52us/step - loss: 0.6930 - val_loss: 0.6927
# Epoch 2/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6917 - val_loss: 0.6901
# Epoch 3/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6874 - val_loss: 0.6844
# Epoch 4/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6815 - val_loss: 0.6788
# Epoch 5/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6754 - val_loss: 0.6730
# Epoch 6/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6695 - val_loss: 0.6681
# Epoch 7/100
# 34153/34153 [==============================] - 0s 11us/step - loss: 0.6650 - val_loss: 0.6646
# Epoch 8/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6620 - val_loss: 0.6624
# Epoch 9/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6597 - val_loss: 0.6605
# Epoch 10/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6579 - val_loss: 0.6590
# Epoch 11/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6563 - val_loss: 0.6577
# Epoch 12/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6550 - val_loss: 0.6564
# Epoch 13/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6538 - val_loss: 0.6554
# Epoch 14/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6528 - val_loss: 0.6545
# Epoch 15/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6519 - val_loss: 0.6537
# Epoch 16/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6511 - val_loss: 0.6527
# Epoch 17/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6453 - val_loss: 0.6410
# Epoch 18/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6349 - val_loss: 0.6343
# Epoch 19/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6296 - val_loss: 0.6305
# Epoch 20/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6267 - val_loss: 0.6286
# Epoch 21/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6252 - val_loss: 0.6275
# Epoch 22/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6242 - val_loss: 0.6267
# Epoch 23/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6234 - val_loss: 0.6261
# Epoch 24/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6229 - val_loss: 0.6256
# Epoch 25/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6225 - val_loss: 0.6253
# Epoch 26/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6221 - val_loss: 0.6251
# Epoch 27/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6219 - val_loss: 0.6248
# Epoch 28/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6217 - val_loss: 0.6246
# Epoch 29/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6215 - val_loss: 0.6245
# Epoch 30/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6214 - val_loss: 0.6244
# Epoch 31/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6213 - val_loss: 0.6243
# Epoch 32/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6213 - val_loss: 0.6242
# Epoch 33/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6212 - val_loss: 0.6242
# Epoch 34/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6211 - val_loss: 0.6241
# Epoch 35/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6211 - val_loss: 0.6241
# Epoch 36/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6210 - val_loss: 0.6240
# Epoch 37/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6210 - val_loss: 0.6240
# Epoch 38/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6210 - val_loss: 0.6240
# Epoch 39/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6209 - val_loss: 0.6239
# Epoch 40/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6209 - val_loss: 0.6239
# Epoch 41/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6209 - val_loss: 0.6239
# Epoch 42/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6208 - val_loss: 0.6239
# Epoch 43/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6208 - val_loss: 0.6238
# Epoch 44/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6208 - val_loss: 0.6238
# Epoch 45/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6208 - val_loss: 0.6238
# Epoch 46/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6208 - val_loss: 0.6238
# Epoch 47/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6207 - val_loss: 0.6237
# Epoch 48/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6207 - val_loss: 0.6237
# Epoch 49/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6207 - val_loss: 0.6237
# Epoch 50/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6207 - val_loss: 0.6237
# Epoch 51/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6207 - val_loss: 0.6237
# Epoch 52/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6207 - val_loss: 0.6236
# Epoch 53/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6206 - val_loss: 0.6236
# Epoch 54/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6206 - val_loss: 0.6236
# Epoch 55/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6206 - val_loss: 0.6236
# Epoch 56/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6206 - val_loss: 0.6236
# Epoch 57/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6206 - val_loss: 0.6236
# Epoch 58/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6206 - val_loss: 0.6236
# Epoch 59/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6206 - val_loss: 0.6236
# Epoch 60/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6206 - val_loss: 0.6236
# Epoch 61/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 62/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6205 - val_loss: 0.6236
# Epoch 63/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 64/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 65/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 66/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 67/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 68/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 69/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 70/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 71/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6204 - val_loss: 0.6235
# Epoch 72/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6204 - val_loss: 0.6235
# Epoch 73/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6205 - val_loss: 0.6235
# Epoch 74/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6204 - val_loss: 0.6234
# Epoch 75/100
# 34153/34153 [==============================] - 0s 11us/step - loss: 0.6204 - val_loss: 0.6234
# Epoch 76/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6204 - val_loss: 0.6234
# Epoch 77/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6204 - val_loss: 0.6234
# Epoch 78/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6204 - val_loss: 0.6234
# Epoch 79/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6204 - val_loss: 0.6234
# Epoch 80/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6204 - val_loss: 0.6234
# Epoch 81/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6204 - val_loss: 0.6234
# Epoch 82/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6204 - val_loss: 0.6234
# Epoch 83/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6203 - val_loss: 0.6234
# Epoch 84/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6203 - val_loss: 0.6234
# Epoch 85/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6203 - val_loss: 0.6234
# Epoch 86/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6203 - val_loss: 0.6234
# Epoch 87/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6203 - val_loss: 0.6234
# Epoch 88/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6203 - val_loss: 0.6234
# Epoch 89/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6203 - val_loss: 0.6233
# Epoch 90/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6203 - val_loss: 0.6233
# Epoch 91/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6203 - val_loss: 0.6233
# Epoch 92/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6203 - val_loss: 0.6233
# Epoch 93/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6203 - val_loss: 0.6233
# Epoch 94/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6203 - val_loss: 0.6233
# Epoch 95/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6202 - val_loss: 0.6233
# Epoch 96/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6202 - val_loss: 0.6233
# Epoch 97/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6202 - val_loss: 0.6233
# Epoch 98/100
# 34153/34153 [==============================] - 0s 13us/step - loss: 0.6202 - val_loss: 0.6233
# Epoch 99/100
# 34153/34153 [==============================] - 0s 14us/step - loss: 0.6202 - val_loss: 0.6233
# Epoch 100/100
# 34153/34153 [==============================] - 0s 12us/step - loss: 0.6202 - val_loss: 0.6233

# %%
plot_history(history)
plot_examples(x_test, decoded_stocks)

# %% [markdown]
# ### LSTM

# %%
inputs = Input(shape=(window_length, 1))
encoded = LSTM(encoding_dim)(inputs)

decoded = RepeatVector(window_length)(encoded)
decoded = LSTM(1, return_sequences=True)(decoded)

sequence_autoencoder = Model(inputs, decoded)
encoder = Model(inputs, encoded)
sequence_autoencoder.summary()

sequence_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = sequence_autoencoder.fit(x_train, x_train,
                epochs=epochs,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test))

decoded_stocks = sequence_autoencoder.predict(x_test)
# Out:
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10, 1)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 3)                 60
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 10, 3)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 1)             20
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 4823 samples, validate on 200 samples
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\HIT-2233\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 4823/4823 [==============================] - 3s 597us/step - loss: 7.9867 - val_loss: 8.3049
# Epoch 2/100
# 4823/4823 [==============================] - 0s 34us/step - loss: 7.6100 - val_loss: 7.4596
# Epoch 3/100
# 4823/4823 [==============================] - 0s 35us/step - loss: 6.6025 - val_loss: 6.1839
# Epoch 4/100
# 4823/4823 [==============================] - 0s 32us/step - loss: 5.0490 - val_loss: 4.2583
# Epoch 5/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 3.0046 - val_loss: 2.4099
# Epoch 6/100
# 4823/4823 [==============================] - 0s 32us/step - loss: 2.1655 - val_loss: 2.1576
# Epoch 7/100
# 4823/4823 [==============================] - 0s 35us/step - loss: 1.9906 - val_loss: 2.0348
# Epoch 8/100
# 4823/4823 [==============================] - 0s 27us/step - loss: 1.8968 - val_loss: 1.9593
# Epoch 9/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 1.8365 - val_loss: 1.9070
# Epoch 10/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 1.7930 - val_loss: 1.8678
# Epoch 11/100
# 4823/4823 [==============================] - 0s 27us/step - loss: 1.7596 - val_loss: 1.8361
# Epoch 12/100
# 4823/4823 [==============================] - 0s 26us/step - loss: 1.7320 - val_loss: 1.8090
# Epoch 13/100
# 4823/4823 [==============================] - 0s 32us/step - loss: 1.7079 - val_loss: 1.7849
# Epoch 14/100
# 4823/4823 [==============================] - 0s 36us/step - loss: 1.6862 - val_loss: 1.7627
# Epoch 15/100
# 4823/4823 [==============================] - 0s 32us/step - loss: 1.6659 - val_loss: 1.7416
# Epoch 16/100
# 4823/4823 [==============================] - 0s 38us/step - loss: 1.6467 - val_loss: 1.7215
# Epoch 17/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 1.6281 - val_loss: 1.7019
# Epoch 18/100
# 4823/4823 [==============================] - 0s 32us/step - loss: 1.6101 - val_loss: 1.6829
# Epoch 19/100
# 4823/4823 [==============================] - 0s 39us/step - loss: 1.5925 - val_loss: 1.6642
# Epoch 20/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 1.5751 - val_loss: 1.6459
# Epoch 21/100
# 4823/4823 [==============================] - 0s 29us/step - loss: 1.5581 - val_loss: 1.6277
# Epoch 22/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 1.5413 - val_loss: 1.6099
# Epoch 23/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 1.5247 - val_loss: 1.5922
# Epoch 24/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 1.5084 - val_loss: 1.5748
# Epoch 25/100
# 4823/4823 [==============================] - 0s 29us/step - loss: 1.4922 - val_loss: 1.5576
# Epoch 26/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 1.4762 - val_loss: 1.5407
# Epoch 27/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 1.4605 - val_loss: 1.5239
# Epoch 28/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 1.4448 - val_loss: 1.5073
# Epoch 29/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 1.4294 - val_loss: 1.4909
# Epoch 30/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 1.4142 - val_loss: 1.4746
# Epoch 31/100
# 4823/4823 [==============================] - 0s 29us/step - loss: 1.3991 - val_loss: 1.4585
# Epoch 32/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 1.3841 - val_loss: 1.4426
# Epoch 33/100
# 4823/4823 [==============================] - 0s 27us/step - loss: 1.3693 - val_loss: 1.4268
# Epoch 34/100
# 4823/4823 [==============================] - 0s 48us/step - loss: 1.3546 - val_loss: 1.4112
# Epoch 35/100
# 4823/4823 [==============================] - 0s 34us/step - loss: 1.3401 - val_loss: 1.3957
# Epoch 36/100
# 4823/4823 [==============================] - 0s 29us/step - loss: 1.3257 - val_loss: 1.3803
# Epoch 37/100
# 4823/4823 [==============================] - 0s 32us/step - loss: 1.3114 - val_loss: 1.3650
# Epoch 38/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 1.2972 - val_loss: 1.3499
# Epoch 39/100
# 4823/4823 [==============================] - 0s 27us/step - loss: 1.2831 - val_loss: 1.3349
# Epoch 40/100
# 4823/4823 [==============================] - 0s 27us/step - loss: 1.2692 - val_loss: 1.3200
# Epoch 41/100
# 4823/4823 [==============================] - 0s 61us/step - loss: 1.2553 - val_loss: 1.3052
# Epoch 42/100
# 4823/4823 [==============================] - 0s 36us/step - loss: 1.2416 - val_loss: 1.2905
# Epoch 43/100
# 4823/4823 [==============================] - 0s 37us/step - loss: 1.2279 - val_loss: 1.2759
# Epoch 44/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 1.2144 - val_loss: 1.2614
# Epoch 45/100
# 4823/4823 [==============================] - 0s 32us/step - loss: 1.2010 - val_loss: 1.2471
# Epoch 46/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 1.1877 - val_loss: 1.2328
# Epoch 47/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 1.1745 - val_loss: 1.2187
# Epoch 48/100
# 4823/4823 [==============================] - 0s 27us/step - loss: 1.1614 - val_loss: 1.2047
# Epoch 49/100
# 4823/4823 [==============================] - 0s 27us/step - loss: 1.1484 - val_loss: 1.1908
# Epoch 50/100
# 4823/4823 [==============================] - 0s 39us/step - loss: 1.1355 - val_loss: 1.1770
# Epoch 51/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 1.1227 - val_loss: 1.1633
# Epoch 52/100
# 4823/4823 [==============================] - 0s 40us/step - loss: 1.1101 - val_loss: 1.1498
# Epoch 53/100
# 4823/4823 [==============================] - 0s 72us/step - loss: 1.0976 - val_loss: 1.1364
# Epoch 54/100
# 4823/4823 [==============================] - 0s 66us/step - loss: 1.0852 - val_loss: 1.1231
# Epoch 55/100
# 4823/4823 [==============================] - 0s 53us/step - loss: 1.0730 - val_loss: 1.1100
# Epoch 56/100
# 4823/4823 [==============================] - 0s 33us/step - loss: 1.0609 - val_loss: 1.0970
# Epoch 57/100
# 4823/4823 [==============================] - 0s 29us/step - loss: 1.0489 - val_loss: 1.0842
# Epoch 58/100
# 4823/4823 [==============================] - 0s 33us/step - loss: 1.0371 - val_loss: 1.0716
# Epoch 59/100
# 4823/4823 [==============================] - 0s 37us/step - loss: 1.0255 - val_loss: 1.0591
# Epoch 60/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 1.0141 - val_loss: 1.0469
# Epoch 61/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 1.0029 - val_loss: 1.0349
# Epoch 62/100
# 4823/4823 [==============================] - 0s 26us/step - loss: 0.9920 - val_loss: 1.0232
# Epoch 63/100
# 4823/4823 [==============================] - 0s 29us/step - loss: 0.9812 - val_loss: 1.0117
# Epoch 64/100
# 4823/4823 [==============================] - 0s 29us/step - loss: 0.9708 - val_loss: 1.0004
# Epoch 65/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 0.9605 - val_loss: 0.9895
# Epoch 66/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 0.9506 - val_loss: 0.9789
# Epoch 67/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 0.9409 - val_loss: 0.9686
# Epoch 68/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 0.9316 - val_loss: 0.9586
# Epoch 69/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 0.9226 - val_loss: 0.9490
# Epoch 70/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 0.9140 - val_loss: 0.9398
# Epoch 71/100
# 4823/4823 [==============================] - 0s 32us/step - loss: 0.9057 - val_loss: 0.9309
# Epoch 72/100
# 4823/4823 [==============================] - 0s 32us/step - loss: 0.8978 - val_loss: 0.9225
# Epoch 73/100
# 4823/4823 [==============================] - 0s 33us/step - loss: 0.8903 - val_loss: 0.9145
# Epoch 74/100
# 4823/4823 [==============================] - 0s 27us/step - loss: 0.8832 - val_loss: 0.9069
# Epoch 75/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 0.8764 - val_loss: 0.8998
# Epoch 76/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 0.8702 - val_loss: 0.8932
# Epoch 77/100
# 4823/4823 [==============================] - 0s 35us/step - loss: 0.8643 - val_loss: 0.8870
# Epoch 78/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 0.8589 - val_loss: 0.8813
# Epoch 79/100
# 4823/4823 [==============================] - 0s 45us/step - loss: 0.8538 - val_loss: 0.8759
# Epoch 80/100
# 4823/4823 [==============================] - 0s 34us/step - loss: 0.8491 - val_loss: 0.8709
# Epoch 81/100
# 4823/4823 [==============================] - 0s 38us/step - loss: 0.8448 - val_loss: 0.8663
# Epoch 82/100
# 4823/4823 [==============================] - 0s 37us/step - loss: 0.8408 - val_loss: 0.8620
# Epoch 83/100
# 4823/4823 [==============================] - 0s 42us/step - loss: 0.8371 - val_loss: 0.8580
# Epoch 84/100
# 4823/4823 [==============================] - 0s 48us/step - loss: 0.8337 - val_loss: 0.8542
# Epoch 85/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 0.8304 - val_loss: 0.8507
# Epoch 86/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 0.8275 - val_loss: 0.8474
# Epoch 87/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 0.8247 - val_loss: 0.8443
# Epoch 88/100
# 4823/4823 [==============================] - 0s 30us/step - loss: 0.8221 - val_loss: 0.8414
# Epoch 89/100
# 4823/4823 [==============================] - 0s 33us/step - loss: 0.8196 - val_loss: 0.8387
# Epoch 90/100
# 4823/4823 [==============================] - 0s 34us/step - loss: 0.8173 - val_loss: 0.8361
# Epoch 91/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 0.8152 - val_loss: 0.8336
# Epoch 92/100
# 4823/4823 [==============================] - 0s 25us/step - loss: 0.8132 - val_loss: 0.8313
# Epoch 93/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 0.8112 - val_loss: 0.8291
# Epoch 94/100
# 4823/4823 [==============================] - 0s 33us/step - loss: 0.8094 - val_loss: 0.8270
# Epoch 95/100
# 4823/4823 [==============================] - 0s 26us/step - loss: 0.8077 - val_loss: 0.8251
# Epoch 96/100
# 4823/4823 [==============================] - 0s 31us/step - loss: 0.8061 - val_loss: 0.8232
# Epoch 97/100
# 4823/4823 [==============================] - 0s 26us/step - loss: 0.8046 - val_loss: 0.8214
# Epoch 98/100
# 4823/4823 [==============================] - 0s 28us/step - loss: 0.8031 - val_loss: 0.8197
# Epoch 99/100
# 4823/4823 [==============================] - 0s 33us/step - loss: 0.8018 - val_loss: 0.8181
# Epoch 100/100
# 4823/4823 [==============================] - 0s 29us/step - loss: 0.8005 - val_loss: 0.8165

# %%
plot_history(history)

# %%
plot_examples(x_test, decoded_stocks)
