# %%
import pandas as pd

# %%
df = pd.read_csv('../data/us_etf_data/SPY.csv')

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  1993-01-29  43.96875  43.96875  43.75000  43.93750  26.706757  1003200
# 1  1993-02-01  43.96875  44.25000  43.96875  44.25000  26.896694   480500
# 2  1993-02-02  44.21875  44.37500  44.12500  44.34375  26.953669   201300
# 3  1993-02-03  44.40625  44.84375  44.37500  44.81250  27.238594   529400
# 4  1993-02-04  44.96875  45.09375  44.46875  45.00000  27.352570   531500

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  6648.000000  6648.000000  6648.000000  6648.000000  6648.000000
# mean    133.762935   134.541071   132.893598   133.759854   110.399391
# std      59.488006    59.671285    59.277882    59.492056    64.113369
# min      43.343750    43.531250    42.812500    43.406250    26.383823
# 25%      96.780937    97.735000    95.726562    96.921875    71.256485
# 50%     124.433750   125.335938   123.500000   124.312500    93.641503
# 75%     151.702503   152.514999   150.810624   151.791713   125.251474
# max     296.040009   296.309998   293.760010   295.859985   294.427979
#
#              Volume
# count  6.648000e+03
# mean   8.440122e+07
# std    9.837713e+07
# min    5.200000e+03
# 25%    6.966775e+06
# 50%    5.709990e+07
# 75%    1.229908e+08
# max    8.710263e+08

# %%
df['CODE'] = 'SPY'

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume CODE
# 0  1993-01-29  43.96875  43.96875  43.75000  43.93750  26.706757  1003200  SPY
# 1  1993-02-01  43.96875  44.25000  43.96875  44.25000  26.896694   480500  SPY
# 2  1993-02-02  44.21875  44.37500  44.12500  44.34375  26.953669   201300  SPY
# 3  1993-02-03  44.40625  44.84375  44.37500  44.81250  27.238594   529400  SPY
# 4  1993-02-04  44.96875  45.09375  44.46875  45.00000  27.352570   531500  SPY

# %%
price_df = df.loc[:,['Date','Adj Close']].copy()

# %%
price_df.head()
# Out:
#          Date  Adj Close
# 0  1993-01-29  26.706757
# 1  1993-02-01  26.896694
# 2  1993-02-02  26.953669
# 3  1993-02-03  27.238594
# 4  1993-02-04  27.352570

# %%
# price_df['DATE'] = price_df['DATE'].map(lambda x : datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S').strftime('%Y-%m-%d'))

# %%
price_df.set_index(['Date'],inplace=True)

# %%
price_df.head()
# Out:
#             Adj Close
# Date
# 1993-01-29  26.706757
# 1993-02-01  26.896694
# 1993-02-02  26.953669
# 1993-02-03  27.238594
# 1993-02-04  27.352570

# %%
price_df['center'] = price_df['Adj Close'].rolling(20).mean() # 이동평균선을 구한다.

# %%
price_df.iloc[18:25]
# Out:
#             Adj Close     center
# Date
# 1993-02-25  26.953669        NaN
# 1993-02-26  26.991682  26.910942
# 1993-03-01  26.915695  26.921389
# 1993-03-02  27.314577  26.942283
# 1993-03-03  27.428545  26.966027
# 1993-03-04  27.276592  26.967927
# 1993-03-05  27.200619  26.960329

# %%
# +2 표준편차를 둔 상단 밴드를 구한다.
price_df['ub'] = price_df['center'] + 2 * price_df['Adj Close'].rolling(20).std()

# %%
price_df.iloc[18:25]
# Out:
#             Adj Close     center         ub
# Date
# 1993-02-25  26.953669        NaN        NaN
# 1993-02-26  26.991682  26.910942  27.598068
# 1993-03-01  26.915695  26.921389  27.601764
# 1993-03-02  27.314577  26.942283  27.644772
# 1993-03-03  27.428545  26.966027  27.701465
# 1993-03-04  27.276592  26.967927  27.706519
# 1993-03-05  27.200619  26.960329  27.685261

# %%
# -2 표준편차를 둔 하단 밴드를 구한다.
price_df['lb'] = price_df['center'] - 2 * price_df['Adj Close'].rolling(20).std()
price_df.iloc[18:25]
# Out:
#             Adj Close     center         ub         lb
# Date
# 1993-02-25  26.953669        NaN        NaN        NaN
# 1993-02-26  26.991682  26.910942  27.598068  26.223816
# 1993-03-01  26.915695  26.921389  27.601764  26.241013
# 1993-03-02  27.314577  26.942283  27.644772  26.239794
# 1993-03-03  27.428545  26.966027  27.701465  26.230589
# 1993-03-04  27.276592  26.967927  27.706519  26.229334
# 1993-03-05  27.200619  26.960329  27.685261  26.235397

# %%
n = 20
sigma = 2

# %%
def bollinger_band(price_df, n, sigma):
    bb = price_df.copy()
    bb['center'] = price_df['Adj Close'].rolling(n).mean() #중앙 이동평균선
    bb['ub'] = bb['center'] + sigma * price_df['Adj Close'].rolling(n).std() # 상단 밴드
    bb['lb'] = bb['center'] - sigma * price_df['Adj Close'].rolling(n).std() # 하단 밴드
    return bb

# %%
bollinger = bollinger_band(price_df, n, sigma)

# %%
bollinger.head(21)
# Out:
#             Adj Close     center         ub         lb
# Date
# 1993-01-29  26.706757        NaN        NaN        NaN
# 1993-02-01  26.896694        NaN        NaN        NaN
# 1993-02-02  26.953669        NaN        NaN        NaN
# 1993-02-03  27.238594        NaN        NaN        NaN
# 1993-02-04  27.352570        NaN        NaN        NaN
# 1993-02-05  27.333586        NaN        NaN        NaN
# 1993-02-08  27.333586        NaN        NaN        NaN
# 1993-02-09  27.143635        NaN        NaN        NaN
# 1993-02-10  27.181616        NaN        NaN        NaN
# 1993-02-11  27.314577        NaN        NaN        NaN
# 1993-02-12  27.105640        NaN        NaN        NaN
# 1993-02-16  26.421825        NaN        NaN        NaN
# 1993-02-17  26.402828        NaN        NaN        NaN
# 1993-02-18  26.383823        NaN        NaN        NaN
# 1993-02-19  26.478807        NaN        NaN        NaN
# 1993-02-22  26.573792        NaN        NaN        NaN
# 1993-02-23  26.554792        NaN        NaN        NaN
# 1993-02-24  26.896694        NaN        NaN        NaN
# 1993-02-25  26.953669        NaN        NaN        NaN
# 1993-02-26  26.991682  26.910942  27.598068  26.223816
# 1993-03-01  26.915695  26.921389  27.601764  26.241013

# %%
base_date = '2009-01-02'

# %%
sample = bollinger.loc[base_date:]
sample.head()
# Out:
#             Adj Close     center         ub         lb
# Date
# 2009-01-02  75.099487  71.378963  74.538229  68.219698
# 2009-01-05  75.010582  71.711677  74.931608  68.491746
# 2009-01-06  75.511505  71.964058  75.543401  68.384716
# 2009-01-07  73.249435  71.980327  75.580937  68.379718
# 2009-01-08  73.548378  72.071645  75.736733  68.406557

# %%
book = sample[['Adj Close']].copy()

# %%
book['trade'] = '' #거래내역 컬럼

# %%
book.head()
# Out:
#             Adj Close trade
# Date
# 2009-01-02  75.099487
# 2009-01-05  75.010582
# 2009-01-06  75.511505
# 2009-01-07  73.249435
# 2009-01-08  73.548378

# %%
def create_trade_book(sample):
    book = sample[['Adj Close']].copy()
    book['trade'] = ''
    return (book)

# %%
book = create_trade_book(sample)

# %%
book.head()
# Out:
#             Adj Close trade
# Date
# 2009-01-02  75.099487
# 2009-01-05  75.010582
# 2009-01-06  75.511505
# 2009-01-07  73.249435
# 2009-01-08  73.548378

# %%
# if sample.loc[i, 'Adj Close'] > sample.loc[i, 'ub']:
#     book.loc[i, 'trade'] = ''

# %%
# elif sample.loc[i, 'lb'] > sample.loc[i, 'Adj Close']:
#     if book.shift(1).loc[i, 'trade'] == 'buy':    
#         book.loc[i, 'trade'] = 'buy'     
#     else:
#         book.loc[i, 'trade'] = 'ready'

# %%
# elif sample.loc[i, 'ub'] >= sample.loc[i, 'Adj Close'] and 
#         sample.loc[i, 'Adj Close'] >= sample.loc[i, 'lb']:
#     if book.shift(1).loc[i, 'trade'] == 'buy' or book.shift(1).loc[i, 'trade'] == 'ready':
#         book.loc[i, 'trade'] = 'buy'
#     else:
#         book.loc[i, 'trade'] = ''

# %%
def tradings(sample, book):
    for i in sample.index:
        if sample.loc[i, 'Adj Close'] > sample.loc[i, 'ub']: # 상단밴드 이탈시 동작 안함
            book.loc[i, 'trade'] = ''
        elif sample.loc[i, 'lb'] > sample.loc[i, 'Adj Close']: # 하반밴드 이탈시 매수 대기
            if book.shift(1).loc[i, 'trade'] == 'buy':    # 이미 매수상태라면
                book.loc[i, 'trade'] = 'buy'     # 매수상태 유지
            else:
                book.loc[i, 'trade'] = 'ready'    # 대기
        elif sample.loc[i, 'ub'] >= sample.loc[i, 'Adj Close'] and sample.loc[i, 'Adj Close'] >= sample.loc[i, 'lb']: # 볼린저 밴드 안에 있을 시
            if book.shift(1).loc[i, 'trade'] == 'buy' or book.shift(1).loc[i, 'trade'] == 'ready':
                book.loc[i, 'trade'] = 'buy'  # 매수상태 유지
            else:
                book.loc[i, 'trade'] = '' # 동작 안함
    return (book)

# %%
book = tradings(sample,book)

# %%
book.tail(10)
# Out:
#              Adj Close trade
# Date
# 2019-06-11  287.501678   buy
# 2019-06-12  286.994171   buy
# 2019-06-13  288.178375   buy
# 2019-06-14  287.859955   buy
# 2019-06-17  287.969391   buy
# 2019-06-18  290.984741   buy
# 2019-06-19  291.641541   buy
# 2019-06-20  294.427979   buy
# 2019-06-21  294.000000   buy
# 2019-06-24  293.640015   buy

# %%
# rtn = 1.0
# book['return'] = 1
# buy = 0.0
# sell = 0.0

# %%
# for i in book.index:
#     if book.loc[i, 'trade'] == 'buy' and book.shift(1).loc[i, 'trade'] == 'ready':     # long 진입
#         buy = book.loc[i, 'Adj Close']

# %%
# rtn = (sell - buy) / buy # 손익 계산

# %%
# for i in book.index:
#     if book.loc[i, 'trade'] == 'buy' and book.shift(1).loc[i, 'trade'] == 'ready':     # long 진입
#         buy = book.loc[i, 'Adj Close']
#         print('진입일 : ',i, 'long 진입가격 : ', buy)
#     elif book.loc[i, 'trade'] == '' and book.shift(1).loc[i, 'trade'] == 'buy':     # long 청산
#         sell = book.loc[i, 'Adj Close']
#         rtn = (sell - buy) / buy # 손익 계산
# #         rtn = (sell - buy) / buy + 1 # 손익 계산
#         book.loc[i, 'return'] = rtn
#         print('청산일 : ',i, 'long 진입가격 : ', buy, ' |  long 청산가격 : ', \
#               sell, ' | return:', round(rtn, 4))
#     if book.loc[i, 'trade'] == '':     # zero position
#         buy = 0.0
#         sell = 0.0

# %%
# for i in book.index:
#     if book.loc[i, 'trade'] == 'buy' and book.shift(1).loc[i, 'trade'] == 'ready':     # long 진입
#         buy = book.loc[i, 'Adj Close']
#         print('진입일 : ',i, 'long 진입가격 : ', buy)
#     elif book.loc[i, 'trade'] == '' and book.shift(1).loc[i, 'trade'] == 'buy':     # long 청산
#         sell = book.loc[i, 'Adj Close']
#         rtn = (sell - buy) / buy # 손익 계산
# #         rtn = (sell - buy) / buy + 1 # 손익 계산
#         book.loc[i, 'return'] = rtn
#         print('청산일 : ',i, 'long 진입가격 : ', buy, ' |  long 청산가격 : ', \
#               sell, ' | return:', round(rtn, 4))
#     if book.loc[i, 'trade'] == '':     # zero position
#         buy = 0.0
#         sell = 0.0

# %%
# acc_rtn = 1.0
# for i in book.index:
#     rtn = book.loc[i, 'return']
#     acc_rtn = acc_rtn * (1+rtn) # 누적 수익률 계산
#     book.loc[i, 'acc return'] = acc_rtn

# %%
# acc_rtn = 1.0
# for i in book.index:
#     rtn = book.loc[i, 'return']
#     acc_rtn = acc_rtn * rtn # 누적 수익률 계산
#     book.loc[i, 'acc return'] = acc_rtn

# %%
def returns(book):
    # 손익 계산
    rtn = 1.0
    book['return'] = 1
    buy = 0.0
    sell = 0.0
    for i in book.index:
        if book.loc[i, 'trade'] == 'buy' and book.shift(1).loc[i, 'trade'] == 'ready':     # long 진입
            buy = book.loc[i, 'Adj Close']
            print('진입일 : ',i, 'long 진입가격 : ', buy)
        elif book.loc[i, 'trade'] == '' and book.shift(1).loc[i, 'trade'] == 'buy':     # long 청산
            sell = book.loc[i, 'Adj Close']
            rtn = (sell - buy) / buy + 1 # 손익 계산
            book.loc[i, 'return'] = rtn
            print('청산일 : ',i, 'long 진입가격 : ', buy, ' |  long 청산가격 : ', \
                  sell, ' | return:', round(rtn, 4))
    
        if book.loc[i, 'trade'] == '':     # zero position
            buy = 0.0
            sell = 0.0
    
    acc_rtn = 1.0
    for i in book.index:
        rtn = book.loc[i, 'return']
        acc_rtn = acc_rtn * rtn  # 누적 수익률 계산
        book.loc[i, 'acc return'] = acc_rtn

    print ('Accunulated return :', round(acc_rtn, 4))
    return (round(acc_rtn, 4))

# %%
print(returns(book))
# Out:
# 진입일 :  2009-01-21 long 진입가격 :  67.90136700000001
# 청산일 :  2009-03-23 long 진입가격 :  67.90136700000001  |  long 청산가격 :  66.898392  | return: 0.9852
# 진입일 :  2010-01-27 long 진입가격 :  90.782265
# 청산일 :  2010-04-14 long 진입가격 :  90.782265  |  long 청산가격 :  100.584618  | return: 1.108
# 진입일 :  2010-05-10 long 진입가격 :  96.409874
# 청산일 :  2010-10-13 long 진입가격 :  96.409874  |  long 청산가격 :  98.862717  | return: 1.0254
# 진입일 :  2011-03-11 long 진입가격 :  110.27156799999999
# 청산일 :  2011-04-26 long 진입가격 :  110.27156799999999  |  long 청산가격 :  114.094101  | return: 1.0347
# 진입일 :  2011-05-24 long 진입가격 :  111.69016299999998
# 청산일 :  2011-06-30 long 진입가격 :  111.69016299999998  |  long 청산가격 :  112.26088  | return: 1.0051
# 진입일 :  2011-08-09 long 진입가격 :  99.934921
# 청산일 :  2012-02-03 long 진입가격 :  99.934921  |  long 청산가격 :  115.768776  | return: 1.1584
# 진입일 :  2012-04-11 long 진입가격 :  118.402184
# 청산일 :  2012-07-03 long 진입가격 :  118.402184  |  long 청산가격 :  119.371857  | return: 1.0082
# 진입일 :  2012-10-25 long 진입가격 :  123.520004
# 청산일 :  2012-12-18 long 진입가격 :  123.520004  |  long 청산가격 :  126.961044  | return: 1.0279
# 진입일 :  2013-06-06 long 진입가격 :  143.767319
# 청산일 :  2013-07-11 long 진입가격 :  143.767319  |  long 청산가격 :  148.711197  | return: 1.0344
# 진입일 :  2013-08-20 long 진입가격 :  147.05925
# 청산일 :  2013-09-11 long 진입가격 :  147.05925  |  long 청산가격 :  150.45195  | return: 1.0231
# 진입일 :  2013-10-09 long 진입가격 :  147.79388400000002
# 청산일 :  2013-10-17 long 진입가격 :  147.79388400000002  |  long 청산가격 :  154.594528  | return: 1.046
# 진입일 :  2014-01-28 long 진입가격 :  160.683167
# 청산일 :  2014-04-02 long 진입가격 :  160.683167  |  long 청산가격 :  170.233917  | return: 1.0594
# 진입일 :  2014-04-14 long 진입가격 :  164.880295
# 청산일 :  2014-05-27 long 진입가격 :  164.880295  |  long 청산가격 :  172.613312  | return: 1.0469
# 진입일 :  2014-08-04 long 진입가격 :  175.58668500000002
# 청산일 :  2014-09-18 long 진입가격 :  175.58668500000002  |  long 청산가격 :  182.76814299999998  | return: 1.0409
# 진입일 :  2014-09-26 long 진입가격 :  180.055923
# 청산일 :  2016-04-13 long 진입가격 :  180.055923  |  long 청산가격 :  195.218124  | return: 1.0842
# 진입일 :  2016-06-28 long 진입가격 :  191.70486499999998
# 청산일 :  2016-08-11 long 진입가격 :  191.70486499999998  |  long 청산가격 :  206.280853  | return: 1.076
# 진입일 :  2016-09-12 long 진입가격 :  204.101547
# 청산일 :  2016-12-07 long 진입가격 :  204.101547  |  long 청산가격 :  212.96461499999998  | return: 1.0434
# 진입일 :  2017-03-22 long 진입가격 :  224.42457599999997
# 청산일 :  2017-04-24 long 진입가격 :  224.42457599999997  |  long 청산가격 :  227.19300800000002  | return: 1.0123
# 진입일 :  2017-07-07 long 진입가격 :  233.05621299999999
# 청산일 :  2017-07-14 long 진입가격 :  233.05621299999999  |  long 청산가격 :  236.37718199999998  | return: 1.0142
# 진입일 :  2017-08-14 long 진입가격 :  237.32052599999997
# 청산일 :  2017-09-11 long 진입가격 :  237.32052599999997  |  long 청산가격 :  239.89070099999998  | return: 1.0108
# 진입일 :  2018-02-06 long 진입가격 :  261.68225099999995
# 청산일 :  2018-05-10 long 진입가격 :  261.68225099999995  |  long 청산가격 :  265.551544  | return: 1.0148
# 진입일 :  2018-06-28 long 진입가격 :  265.635925
# 청산일 :  2018-08-07 long 진입가격 :  265.635925  |  long 청산가격 :  280.04098500000003  | return: 1.0542
# 진입일 :  2018-10-16 long 진입가격 :  276.206146
# 청산일 :  2019-03-18 long 진입가격 :  276.206146  |  long 청산가격 :  280.96347000000003  | return: 1.0172
# 진입일 :  2019-05-14 long 진입가격 :  282.02828999999997
# Accunulated return : 2.4555
# 2.4555

# %%
import matplotlib.pylab as plt

# %%
book['acc return'].plot()

# %%
book.tail()
# Out:
#              Adj Close trade  return  acc return
# Date
# 2019-06-18  290.984741   buy     1.0    2.455451
# 2019-06-19  291.641541   buy     1.0    2.455451
# 2019-06-20  294.427979   buy     1.0    2.455451
# 2019-06-21  294.000000   buy     1.0    2.455451
# 2019-06-24  293.640015   buy     1.0    2.455451

# %%
# plt.plot(book['acc return'])
