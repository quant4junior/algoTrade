# %%
import sys
sys.version
# Out:
# '3.5.5 | packaged by conda-forge | (default, Jul 24 2018, 01:52:17) [MSC v.1900 64 bit (AMD64)]'

# %%
import zipline
from zipline.api import order, record, symbol
import pandas as pd
import pandas_datareader as pdr
import pyfolio as pf

# %%
def initialize(context):
    pass

def handle_data(context, data):
    order(symbol('AAPL'), 1)
    record(AAPL=data.current(symbol('AAPL'), 'price'))

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
df = pd.read_csv('AAPL.csv',index_col=['Date'])
df.index = pd.to_datetime(df.index)
# data = data.tz_localize('UTC')

data = df[['Adj Close']]
data.columns = ['AAPL']
data = data.tz_localize('UTC')

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 1980-12-12  0.513393  0.515625  0.513393  0.513393   0.410525  117258400.0
# 1980-12-15  0.488839  0.488839  0.486607  0.486607   0.389106   43971200.0
# 1980-12-16  0.453125  0.453125  0.450893  0.450893   0.360548   26432000.0
# 1980-12-17  0.462054  0.464286  0.462054  0.462054   0.369472   21610400.0
# 1980-12-18  0.475446  0.477679  0.475446  0.475446   0.380182   18362400.0

# %%
data

# %%
type(data.index[0])
# Out:
# pandas._libs.tslib.Timestamp

# %%
# 실행
result = zipline.run_algorithm(start=data.index[0], end=data.index[-1], initialize=initialize, capital_base=1000,
                               handle_data=handle_data, data=data)

# %%
backtest_df = result.copy()
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(backtest_df)

# pf.create_returns_tear_sheet(result['returns'])
pf.create_full_tear_sheet(returns=returns.fillna(0), positions=positions,
                          transactions=transactions,
                          benchmark_rets=None)
# Out:
# C:\Users\HIT-2233\Anaconda3\envs\env_zipline\lib\site-packages\empyrical\stats.py:1477: RuntimeWarning: invalid value encountered in log1p
#   cum_log_returns = np.log1p(returns).cumsum()
# C:\Users\HIT-2233\Anaconda3\envs\env_zipline\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\HIT-2233\Anaconda3\envs\env_zipline\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\HIT-2233\Anaconda3\envs\env_zipline\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1990-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-06-24</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>353</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>27.3%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>122400.3%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>769.9%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.20</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-136.6%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.18</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>23.58</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1776.53</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-96.7%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>1.84</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>0.1%</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\HIT-2233\AppData\Roaming\Python\Python35\site-packages\numpy\core\fromnumeric.py:56: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return getattr(obj, method)(*args, **kwds)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>136.60</td>
#       <td>1993-01-14</td>
#       <td>1997-12-23</td>
#       <td>1998-08-17</td>
#       <td>1458</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>107.20</td>
#       <td>2000-03-22</td>
#       <td>2003-04-17</td>
#       <td>2004-11-22</td>
#       <td>1219</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>70.04</td>
#       <td>2007-12-28</td>
#       <td>2009-01-20</td>
#       <td>2009-10-20</td>
#       <td>473</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>59.16</td>
#       <td>1999-01-13</td>
#       <td>1999-03-11</td>
#       <td>1999-05-03</td>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>57.04</td>
#       <td>1998-08-21</td>
#       <td>1998-10-08</td>
#       <td>1999-01-05</td>
#       <td>98</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dotcom</th>
#       <td>0.13%</td>
#       <td>-12.66%</td>
#       <td>14.34%</td>
#     </tr>
#     <tr>
#       <th>Lehman</th>
#       <td>-0.95%</td>
#       <td>-22.58%</td>
#       <td>10.67%</td>
#     </tr>
#     <tr>
#       <th>9/11</th>
#       <td>-61.47%</td>
#       <td>-847.23%</td>
#       <td>407.42%</td>
#     </tr>
#     <tr>
#       <th>US downgrade/European Debt Crisis</th>
#       <td>-0.00%</td>
#       <td>-6.36%</td>
#       <td>6.92%</td>
#     </tr>
#     <tr>
#       <th>Fukushima</th>
#       <td>-0.26%</td>
#       <td>-5.17%</td>
#       <td>3.04%</td>
#     </tr>
#     <tr>
#       <th>US Housing</th>
#       <td>2.78%</td>
#       <td>-19.92%</td>
#       <td>41.82%</td>
#     </tr>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>-0.28%</td>
#       <td>-2.92%</td>
#       <td>2.74%</td>
#     </tr>
#     <tr>
#       <th>Aug07</th>
#       <td>0.31%</td>
#       <td>-6.56%</td>
#       <td>6.68%</td>
#     </tr>
#     <tr>
#       <th>Mar08</th>
#       <td>1.08%</td>
#       <td>-3.93%</td>
#       <td>7.86%</td>
#     </tr>
#     <tr>
#       <th>Sept08</th>
#       <td>-2.23%</td>
#       <td>-22.58%</td>
#       <td>10.67%</td>
#     </tr>
#     <tr>
#       <th>2009Q1</th>
#       <td>0.27%</td>
#       <td>-7.54%</td>
#       <td>10.01%</td>
#     </tr>
#     <tr>
#       <th>2009Q2</th>
#       <td>1.00%</td>
#       <td>-5.82%</td>
#       <td>10.02%</td>
#     </tr>
#     <tr>
#       <th>Flash Crash</th>
#       <td>-0.38%</td>
#       <td>-4.96%</td>
#       <td>9.10%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>0.57%</td>
#       <td>-1.93%</td>
#       <td>10.12%</td>
#     </tr>
#     <tr>
#       <th>Oct14</th>
#       <td>0.37%</td>
#       <td>-1.84%</td>
#       <td>3.22%</td>
#     </tr>
#     <tr>
#       <th>Fall2015</th>
#       <td>-0.15%</td>
#       <td>-7.34%</td>
#       <td>7.01%</td>
#     </tr>
#     <tr>
#       <th>Low Volatility Bull Market</th>
#       <td>0.32%</td>
#       <td>-11.97%</td>
#       <td>15.60%</td>
#     </tr>
#     <tr>
#       <th>GFC Crash</th>
#       <td>0.03%</td>
#       <td>-22.58%</td>
#       <td>19.18%</td>
#     </tr>
#     <tr>
#       <th>Recovery</th>
#       <td>0.23%</td>
#       <td>-7.46%</td>
#       <td>10.04%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.10%</td>
#       <td>-14.69%</td>
#       <td>10.12%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAPL</th>
#       <td>323187.47%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAPL</th>
#       <td>-50936.04%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAPL</th>
#       <td>323187.47%</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\HIT-2233\Anaconda3\envs\env_zipline\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# # data 가져오기
# ticker = 'AAPL'
# start_date = '2015-01-01'
# end_date = '2019-12-31'
# df = pdr.DataReader('AAPL','yahoo','01/01/2011')['Adj Close']
# df.index = pd.to_datetime(df.index)
# data = df[['Adj Close']]
# data.columns = ['AAPL']
# data = data.tz_localize('UTC')
